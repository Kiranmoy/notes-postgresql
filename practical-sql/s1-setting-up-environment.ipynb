# %% [markdown]
# # Downloading Code and Data from GitHub

# %% [markdown]
# 1. Visit the book’s page on the No Starch Press website at `https://nostarch.com/practical-sql-2nd-edition/`.
# 2. On the page, click **Download the code from GitHub** to visit the repository on `https://github.com/` that holds the material.
# 3. On the Practical SQL 2nd Edition page at GitHub, you should see a Code button. Click it, and then select **Download ZIP** to save the ZIP file to your computer. Place it in a location where you can easily find it, such as your desktop. (If you’re a GitHub user, you can also clone or fork the repository.)
#
# > **shortcut:** https://github.com/anthonydb/practical-sql-2/
#
# ![image.png](attachment:c49e07ae-2ce6-47dd-837b-ff1594b4b71f.png)

# %% [markdown]
# # Installing PostgreSQL and pgAdmin

# %% [markdown]
# https://www.postgresql.org/download/windows/

# %% [markdown]
# ## Install PostgreSQL

# %% [markdown]
# ![image.png](attachment:eb193524-0fd0-4ad6-a74e-4578dc584206.png)
#
# ---
#
# ![image.png](attachment:e4433ac6-d0a9-45cc-a770-c98960a87ae7.png)
#
# ---
#
# ![image.png](attachment:61bd43a9-8a25-4418-b1d8-3e6cdb73b59c.png)
#
# ---
#
# ![image.png](attachment:c2893885-8565-4246-b4b5-47149347a75d.png)
#
# ---
#
# ![image.png](attachment:d9ce94a2-0bed-4ed2-b0bf-04245a973447.png)
#
# Password: **Postgre@Jan2025**
#
# ---
#
# ![image.png](attachment:c0938e2c-53a9-4f48-adf3-02234fa70e73.png)
#
# ---
#
# ![image.png](attachment:36ca4d91-04d8-4a03-8e7d-900b40617e2c.png)
#
# ---
#
# ![image.png](attachment:4993085b-0bbf-4303-a590-e5879cbc26fc.png)
#
# ---
#
# ![image.png](attachment:ded62918-efb3-499a-bd0d-0f12d51648fe.png)
#
# ---
#
# ![image.png](attachment:f7dfe774-80b3-4536-9889-f2b58b76ca10.png)
#
# ---
#
# ![image.png](attachment:bf65bd6d-4517-47a2-9ce1-0914c4eeefd7.png)

# %% [markdown]
# ## Install Stack Builder

# %% [markdown]
# ![image.png](attachment:1ab98d7b-43bf-491f-ad87-c987781ad2cf.png)
#
# ---
#
# ![image.png](attachment:7a8ffc2d-3863-463e-9722-deddbeb9b950.png)
#
# ---
#
# ![image.png](attachment:c475a49f-b275-4621-ab24-04fe41886b65.png)
#
# ---
#
# ![image.png](attachment:4f62ce28-7d84-4cc6-b87f-8cab35cc5e8f.png)
#
# ---
#
# ![image.png](attachment:80a06168-389c-4353-ab9a-739e9325e9f6.png)
#
# ---
#
# ![image.png](attachment:0465737e-079e-4e24-a688-d1c87ecf7166.png)
#
#
# ---
#
# ![image.png](attachment:ae405337-ca46-4bfa-b3e6-e835f6e3014e.png)
#
# localhost, postgres/**Postgre@Jan2025**, 5432
#
# ---
#
# ![image.png](attachment:d87d7d4e-3dac-4156-89ea-03534fe6c31b.png)
#
# Password: **Postgre@Jan2025**
#
# ---
#
# ![image.png](attachment:a053b742-58d0-4b99-933d-5c6a679a5e2f.png)
#
# ---
#
# ![image.png](attachment:e2501e69-82be-43a3-8ece-bbcb8ac999e9.png)
#
# ---
#
# ![image.png](attachment:974da5a5-badf-4d62-a856-7515b9a33e83.png)
#
# ---
#
# ![image.png](attachment:b9184844-fba9-48d0-bfa0-0d56649e92b4.png)
#
# ---
#
# ![image.png](attachment:3206bc23-8503-42a9-bbbb-4b9849aa8a69.png)
#
# postgres
# Postgre@Jan2025
# 5432
#
# ---
#
# ![image.png](attachment:67d27cb9-91c9-4853-9d93-ac4e801c9be4.png)
#
# Database Name: **postgis_35_kiran**
#
# ---
#
# ![image.png](attachment:8acb5702-be08-464e-8c77-0a5fcf0f55f5.png)
#
# ---
#
# ![image.png](attachment:e063111c-b546-4cb3-9020-786222db29f4.png)

# %% [markdown]
# # Launching pgAdmin and Setting a Master Password

# %% [markdown]
# **Windows:** Go to the **Start menu**, find the PostgreSQL folder for the version you installed, click it, and then select **pgAdmin4**.
#
# Master Password: **Postgre@Jan2025**
#
# ![image.png](attachment:f8889466-b780-4d7e-93d0-00c47386f03e.png)
